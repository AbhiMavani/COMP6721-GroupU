# %%
import pandas as pd
import pandas

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import time
import json
import copy
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import numpy as np
from PIL import Image
from collections import OrderedDict
import cv2
import sys
import argparse

import torch
from torch import nn, optim
from torch.optim import lr_scheduler
from torch.autograd import Variable, Function
from torchvision import datasets, models, transforms, utils
import torchvision
import torch.nn.functional as F
import torch.nn as nn

# %%
image_data_transforms = {
    'training': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'validation': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'testing': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
}

# %%
import zipfile

zip_path = "/content/FLower_Classification.zip"
destination_dir = "/content/dataset"

# !mkdir -p {destination_dir}

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(destination_dir)

print("Dataset unzipped successfully!")
# Out:
# Dataset unzipped successfully!

# %%
import os
# !pip install split-folders
import splitfolders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
splitfolders.ratio('/content/dataset/flowers', output="./Data", seed=1337, ratio=(.8, .1, .1)) # default values
# Out:
# Copying files: 11200 files [00:02, 4410.64 files/s]

# %%
def load_data(batch_size, input_size = (224, 224 ,3),image_data_transforms=None):
    training_path = '/content/Data/train'
    validation_path = '/content/Data/val'
    testing_path = '/content/Data/test'

    train_data = torchvision.datasets.ImageFolder(training_path, transform=image_data_transforms['training'])
    validation_data = torchvision.datasets.ImageFolder(validation_path, transform=image_data_transforms['validation'])
    test_data = torchvision.datasets.ImageFolder(testing_path, transform=image_data_transforms['testing'])

    train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
    validation_loader = torch.utils.data.DataLoader(validation_data, batch_size=batch_size, shuffle=False)
    test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader, validation_loader

# %%
#DenseNet

import torchvision.models as models
from torchvision.models import resnet18, ResNet18_Weights

class CNN(nn.Module):
    def __init__(self,inputDims) -> None:
        super(CNN , self).__init__()

        self.pretrained = models.densenet121(weights=None)

        self.fc_layer = nn.Sequential(
                    nn.Linear(1024, 512),
                    nn.ReLU(inplace=True),
                    nn.Dropout(p=0.1),

                    nn.Linear(512, 256),
                    nn.ReLU(inplace=True),
                    nn.Dropout(p=0.1),

                    nn.Linear(256, 128),
                    nn.ReLU(inplace=True),
                    nn.Dropout(p=0.1),

                    nn.Linear(128, 11)
                )

        self.pretrained.classifier = self.fc_layer
        self.features = {}
        self.pretrained.classifier.register_forward_pre_hook(self.get_features("embeddings"))

    def get_features(self,name):
        def hook(model, input):
            self.features[name] = input[0].detach().cpu().numpy()
        return hook

    def forward(self, x):
          x = self.pretrained(x)
          return x

model2 = CNN((224,224))
print(model2)
# Out:
# CNN(
#   (pretrained): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition1): _Transition(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock2): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition2): _Transition(
#         (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock3): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition3): _Transition(
#         (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock4): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=512, out_features=256, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=256, out_features=128, bias=True)
#       (7): ReLU(inplace=True)
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=128, out_features=11, bias=True)
#     )
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=256, out_features=128, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=128, out_features=11, bias=True)
#   )
# )

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from matplotlib import cm


def visualize(model , data_loader):

  class2idx = {'bellflower': 0, 'daisy': 1, 'dandelion': 2, 'lotus': 3,'rose': 4, 'sunflower':5, 'tulip': 6}
  idx2class = { value : key for key,value in  class2idx.items() }

  embeddings = np.array([])
  labels = np.array([])
  model.eval()

  out_features = 1024
  num_categories = 11

  with torch.no_grad():
    for i,data in enumerate(data_loader):
        images, labs = data[0].to(device), data[1].to(device)
        _ = model(images)

        embeds = model.features["embeddings"].reshape(-1, out_features)
        embeddings = np.append(embeddings , embeds)
        labels = np.append(labels,labs.cpu())

  model.train()

  embeddings = embeddings.reshape(-1, 1024)
  print(embeddings)
  c_labels = labels.reshape(-1 , 1).ravel()

  tsne = TSNE(n_components=2).fit_transform(embeddings)
  labels = np.array([ idx2class[ele] for ele in c_labels])

  cmap = cm.get_cmap('tab20')

  for lab in range(num_categories):
      indices = (c_labels == lab)
      plt.scatter(tsne[indices, 0],
                tsne[indices, 1],
                c=np.array(cmap(lab)).reshape(1, 4),
                label=lab,
                alpha=1)
  plt.legend(fontsize='large', markerscale=2)
  plt.show()

# %%
def evaluate(model , data_loader):
  model.eval()
  accuracy = 0
  with torch.no_grad():
      correct = 0
      total = 0
      for data in data_loader:
          images, labels = data[0].to(device), data[1].to(device)
          outputs = model(images)
          loss = criterion(outputs, labels)
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()

      accuracy = (correct / total) * 100

  model.train()

  return accuracy,loss.item()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
hyperparameters = {
  'lr' : 0.001,
  'batchsize' : 32,
  'epochs' : 25,
  'steps' : 8750,
  'decayRate' : 0.1
}

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

root_path = '/content/drive/MyDrive/'

file_path = 'ai_results/'

filename = 'flower_results/'

test_model_path = 'AI/flowers/densenet/'

path = {
    'test_model_path' : root_path + test_model_path,
    'csv_file' : root_path + file_path + filename
}
# Out:
# Mounted at /content/drive

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))
model = CNN((224,224))
model.to(device)

train_loader , test_loader , val_loader = load_data(batch_size = hyperparameters["batchsize"], input_size = (224,224,3) , image_data_transforms = image_data_transforms)

print(len(train_loader))
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(),lr= hyperparameters["lr"])

scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = hyperparameters['steps'], gamma=hyperparameters['decayRate'])
num_epochs = hyperparameters["epochs"]
total_steps = len(train_loader)

training_accuracy_array = np.array([])
training_loss_array =  np.array([])
validation_accuracy_array =  np.array([])
validation_loss_array =   np.array([])
num_of_epoch_array = np.array([])
max_accuracy = 0

t1 = time.time()
for epoch in range(num_epochs):
    max_accuracy = 0.0
    epoch_loss = 0.0
    epoch_accuracy = 0.0
    for i, data in enumerate(train_loader):
        images, labels = data[0].to(device), data[1].to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total = labels.size(0)
        _,predicted = torch.max(outputs.data, 1)

        correct = (predicted == labels).sum().item()
        if (i + 1) % 25 == 0:
            accuracy = (correct / total) * 100
            validation_accuracy , validation_loss = evaluate(model , val_loader)
            epoch_loss = loss.item()
            epoch_accuracy = accuracy
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Train Accuracy: {:.2f}%, Validation Accuracy: {:.2f}%'.format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(), accuracy , validation_accuracy))

    validation_accuracy , validation_loss = evaluate(model , val_loader)
    num_of_epoch_array = np.append(num_of_epoch_array,epoch+1)
    training_accuracy_array = np.append(training_accuracy_array,epoch_accuracy)
    validation_accuracy_array = np.append(validation_accuracy_array, validation_accuracy)
    training_loss_array = np.append(training_loss_array,epoch_loss)
    validation_loss_array= np.append(validation_loss_array, validation_loss)

    if validation_accuracy > max_accuracy :
      max_accuracy = validation_accuracy
      torch.save(model.state_dict() , path["test_model_path"] + 'best_model.pt')

print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Device: cuda:0
# 280
# Epoch [1/25], Step [25/280], Loss: 1.7364, Train Accuracy: 37.50%, Validation Accuracy: 43.39%
# Epoch [1/25], Step [50/280], Loss: 1.4739, Train Accuracy: 40.62%, Validation Accuracy: 46.07%
# Epoch [1/25], Step [75/280], Loss: 1.5994, Train Accuracy: 28.12%, Validation Accuracy: 37.41%
# Epoch [1/25], Step [100/280], Loss: 1.3240, Train Accuracy: 59.38%, Validation Accuracy: 50.98%
# Epoch [1/25], Step [125/280], Loss: 1.3657, Train Accuracy: 43.75%, Validation Accuracy: 47.95%
# Epoch [1/25], Step [150/280], Loss: 1.4811, Train Accuracy: 37.50%, Validation Accuracy: 46.88%
# Epoch [1/25], Step [175/280], Loss: 1.4536, Train Accuracy: 46.88%, Validation Accuracy: 49.73%
# Epoch [1/25], Step [200/280], Loss: 1.2069, Train Accuracy: 46.88%, Validation Accuracy: 53.75%
# Epoch [1/25], Step [225/280], Loss: 1.2163, Train Accuracy: 53.12%, Validation Accuracy: 55.09%
# Epoch [1/25], Step [250/280], Loss: 1.2375, Train Accuracy: 50.00%, Validation Accuracy: 57.95%
# Epoch [1/25], Step [275/280], Loss: 1.2627, Train Accuracy: 56.25%, Validation Accuracy: 57.68%
# Epoch [2/25], Step [25/280], Loss: 1.3739, Train Accuracy: 50.00%, Validation Accuracy: 56.61%
# Epoch [2/25], Step [50/280], Loss: 1.3887, Train Accuracy: 50.00%, Validation Accuracy: 59.11%
# Epoch [2/25], Step [75/280], Loss: 1.1652, Train Accuracy: 56.25%, Validation Accuracy: 59.02%
# Epoch [2/25], Step [100/280], Loss: 0.8975, Train Accuracy: 71.88%, Validation Accuracy: 56.88%
# Epoch [2/25], Step [125/280], Loss: 1.1056, Train Accuracy: 62.50%, Validation Accuracy: 59.91%
# Epoch [2/25], Step [150/280], Loss: 1.1130, Train Accuracy: 56.25%, Validation Accuracy: 63.39%
# Epoch [2/25], Step [175/280], Loss: 1.1772, Train Accuracy: 46.88%, Validation Accuracy: 52.77%
# Epoch [2/25], Step [200/280], Loss: 0.7889, Train Accuracy: 75.00%, Validation Accuracy: 62.50%
# Epoch [2/25], Step [225/280], Loss: 1.0885, Train Accuracy: 59.38%, Validation Accuracy: 60.45%
# Epoch [2/25], Step [250/280], Loss: 1.1938, Train Accuracy: 50.00%, Validation Accuracy: 62.95%
# Epoch [2/25], Step [275/280], Loss: 1.3916, Train Accuracy: 62.50%, Validation Accuracy: 63.04%
# Epoch [3/25], Step [25/280], Loss: 0.9212, Train Accuracy: 68.75%, Validation Accuracy: 64.29%
# Epoch [3/25], Step [50/280], Loss: 0.8590, Train Accuracy: 68.75%, Validation Accuracy: 63.48%
# Epoch [3/25], Step [75/280], Loss: 1.2819, Train Accuracy: 62.50%, Validation Accuracy: 64.91%
# Epoch [3/25], Step [100/280], Loss: 0.8086, Train Accuracy: 71.88%, Validation Accuracy: 68.12%
# Epoch [3/25], Step [125/280], Loss: 1.0701, Train Accuracy: 53.12%, Validation Accuracy: 64.20%
# Epoch [3/25], Step [150/280], Loss: 0.8227, Train Accuracy: 71.88%, Validation Accuracy: 65.54%
# Epoch [3/25], Step [175/280], Loss: 0.9360, Train Accuracy: 59.38%, Validation Accuracy: 65.09%
# Epoch [3/25], Step [200/280], Loss: 0.8559, Train Accuracy: 75.00%, Validation Accuracy: 67.77%
# Epoch [3/25], Step [225/280], Loss: 1.1879, Train Accuracy: 59.38%, Validation Accuracy: 65.09%
# Epoch [3/25], Step [250/280], Loss: 1.1244, Train Accuracy: 56.25%, Validation Accuracy: 66.43%
# Epoch [3/25], Step [275/280], Loss: 0.7842, Train Accuracy: 75.00%, Validation Accuracy: 68.12%
# Epoch [4/25], Step [25/280], Loss: 0.8772, Train Accuracy: 59.38%, Validation Accuracy: 68.04%
# Epoch [4/25], Step [50/280], Loss: 1.4175, Train Accuracy: 53.12%, Validation Accuracy: 64.20%
# Epoch [4/25], Step [75/280], Loss: 0.8812, Train Accuracy: 75.00%, Validation Accuracy: 65.00%
# Epoch [4/25], Step [100/280], Loss: 1.1060, Train Accuracy: 65.62%, Validation Accuracy: 67.59%
# Epoch [4/25], Step [125/280], Loss: 1.3252, Train Accuracy: 53.12%, Validation Accuracy: 68.75%
# Epoch [4/25], Step [150/280], Loss: 0.9973, Train Accuracy: 68.75%, Validation Accuracy: 69.11%
# Epoch [4/25], Step [175/280], Loss: 0.8212, Train Accuracy: 71.88%, Validation Accuracy: 68.66%
# Epoch [4/25], Step [200/280], Loss: 0.8347, Train Accuracy: 65.62%, Validation Accuracy: 69.20%
# Epoch [4/25], Step [225/280], Loss: 0.7380, Train Accuracy: 71.88%, Validation Accuracy: 67.50%
# Epoch [4/25], Step [250/280], Loss: 1.2554, Train Accuracy: 56.25%, Validation Accuracy: 67.68%
# Epoch [4/25], Step [275/280], Loss: 0.9062, Train Accuracy: 75.00%, Validation Accuracy: 70.27%
# Epoch [5/25], Step [25/280], Loss: 1.1055, Train Accuracy: 50.00%, Validation Accuracy: 71.16%
# Epoch [5/25], Step [50/280], Loss: 0.5354, Train Accuracy: 78.12%, Validation Accuracy: 72.50%
# Epoch [5/25], Step [75/280], Loss: 0.6827, Train Accuracy: 75.00%, Validation Accuracy: 67.59%
# Epoch [5/25], Step [100/280], Loss: 0.9570, Train Accuracy: 56.25%, Validation Accuracy: 66.43%
# Epoch [5/25], Step [125/280], Loss: 0.7121, Train Accuracy: 75.00%, Validation Accuracy: 64.73%
# Epoch [5/25], Step [150/280], Loss: 0.7947, Train Accuracy: 75.00%, Validation Accuracy: 69.64%
# Epoch [5/25], Step [175/280], Loss: 0.7804, Train Accuracy: 68.75%, Validation Accuracy: 72.32%
# Epoch [5/25], Step [200/280], Loss: 0.5225, Train Accuracy: 78.12%, Validation Accuracy: 74.46%
# Epoch [5/25], Step [225/280], Loss: 0.7265, Train Accuracy: 75.00%, Validation Accuracy: 72.50%
# Epoch [5/25], Step [250/280], Loss: 0.6595, Train Accuracy: 78.12%, Validation Accuracy: 72.41%
# Epoch [5/25], Step [275/280], Loss: 0.7137, Train Accuracy: 65.62%, Validation Accuracy: 72.05%
# Epoch [6/25], Step [25/280], Loss: 0.5328, Train Accuracy: 81.25%, Validation Accuracy: 73.84%
# Epoch [6/25], Step [50/280], Loss: 0.6034, Train Accuracy: 78.12%, Validation Accuracy: 74.29%
# Epoch [6/25], Step [75/280], Loss: 0.6890, Train Accuracy: 78.12%, Validation Accuracy: 74.91%
# Epoch [6/25], Step [100/280], Loss: 0.6808, Train Accuracy: 75.00%, Validation Accuracy: 73.48%
# Epoch [6/25], Step [125/280], Loss: 0.7252, Train Accuracy: 78.12%, Validation Accuracy: 74.29%
# Epoch [6/25], Step [150/280], Loss: 0.6414, Train Accuracy: 78.12%, Validation Accuracy: 65.89%
# Epoch [6/25], Step [175/280], Loss: 0.9954, Train Accuracy: 62.50%, Validation Accuracy: 76.43%
# Epoch [6/25], Step [200/280], Loss: 0.5252, Train Accuracy: 84.38%, Validation Accuracy: 73.84%
# Epoch [6/25], Step [225/280], Loss: 1.0193, Train Accuracy: 62.50%, Validation Accuracy: 72.14%
# Epoch [6/25], Step [250/280], Loss: 0.8761, Train Accuracy: 75.00%, Validation Accuracy: 75.62%
# Epoch [6/25], Step [275/280], Loss: 1.0802, Train Accuracy: 68.75%, Validation Accuracy: 75.54%
# Epoch [7/25], Step [25/280], Loss: 0.6278, Train Accuracy: 78.12%, Validation Accuracy: 72.95%
# Epoch [7/25], Step [50/280], Loss: 0.9913, Train Accuracy: 62.50%, Validation Accuracy: 76.25%
# Epoch [7/25], Step [75/280], Loss: 1.3184, Train Accuracy: 62.50%, Validation Accuracy: 73.75%
# Epoch [7/25], Step [100/280], Loss: 0.9707, Train Accuracy: 65.62%, Validation Accuracy: 76.61%
# Epoch [7/25], Step [125/280], Loss: 0.7126, Train Accuracy: 71.88%, Validation Accuracy: 74.29%
# Epoch [7/25], Step [150/280], Loss: 0.5006, Train Accuracy: 81.25%, Validation Accuracy: 75.36%
# Epoch [7/25], Step [175/280], Loss: 0.8997, Train Accuracy: 75.00%, Validation Accuracy: 74.55%
# Epoch [7/25], Step [200/280], Loss: 0.4999, Train Accuracy: 87.50%, Validation Accuracy: 73.66%
# Epoch [7/25], Step [225/280], Loss: 0.4592, Train Accuracy: 81.25%, Validation Accuracy: 76.52%
# Epoch [7/25], Step [250/280], Loss: 0.5786, Train Accuracy: 71.88%, Validation Accuracy: 77.68%
# Epoch [7/25], Step [275/280], Loss: 0.5764, Train Accuracy: 81.25%, Validation Accuracy: 78.21%
# Epoch [8/25], Step [25/280], Loss: 0.4279, Train Accuracy: 84.38%, Validation Accuracy: 76.16%
# Epoch [8/25], Step [50/280], Loss: 0.4635, Train Accuracy: 87.50%, Validation Accuracy: 76.34%
# Epoch [8/25], Step [75/280], Loss: 0.5447, Train Accuracy: 71.88%, Validation Accuracy: 79.38%
# Epoch [8/25], Step [100/280], Loss: 0.8123, Train Accuracy: 71.88%, Validation Accuracy: 78.30%
# Epoch [8/25], Step [125/280], Loss: 0.9220, Train Accuracy: 81.25%, Validation Accuracy: 75.54%
# Epoch [8/25], Step [150/280], Loss: 0.9078, Train Accuracy: 78.12%, Validation Accuracy: 77.23%
# Epoch [8/25], Step [175/280], Loss: 0.5110, Train Accuracy: 81.25%, Validation Accuracy: 79.02%
# Epoch [8/25], Step [200/280], Loss: 0.5694, Train Accuracy: 78.12%, Validation Accuracy: 74.82%
# Epoch [8/25], Step [225/280], Loss: 0.7307, Train Accuracy: 75.00%, Validation Accuracy: 75.80%
# Epoch [8/25], Step [250/280], Loss: 1.4216, Train Accuracy: 68.75%, Validation Accuracy: 78.57%
# Epoch [8/25], Step [275/280], Loss: 0.5511, Train Accuracy: 78.12%, Validation Accuracy: 78.30%
# Epoch [9/25], Step [25/280], Loss: 0.7117, Train Accuracy: 81.25%, Validation Accuracy: 75.45%
# Epoch [9/25], Step [50/280], Loss: 1.0925, Train Accuracy: 71.88%, Validation Accuracy: 73.75%
# Epoch [9/25], Step [75/280], Loss: 0.5403, Train Accuracy: 84.38%, Validation Accuracy: 75.09%
# Epoch [9/25], Step [100/280], Loss: 0.3740, Train Accuracy: 90.62%, Validation Accuracy: 81.34%
# Epoch [9/25], Step [125/280], Loss: 0.9481, Train Accuracy: 62.50%, Validation Accuracy: 76.43%
# Epoch [9/25], Step [150/280], Loss: 0.5416, Train Accuracy: 81.25%, Validation Accuracy: 75.54%
# Epoch [9/25], Step [175/280], Loss: 0.8057, Train Accuracy: 84.38%, Validation Accuracy: 78.12%
# Epoch [9/25], Step [200/280], Loss: 0.3555, Train Accuracy: 93.75%, Validation Accuracy: 79.46%
# Epoch [9/25], Step [225/280], Loss: 0.5079, Train Accuracy: 78.12%, Validation Accuracy: 81.34%
# Epoch [9/25], Step [250/280], Loss: 0.5368, Train Accuracy: 78.12%, Validation Accuracy: 79.11%
# Epoch [9/25], Step [275/280], Loss: 0.3720, Train Accuracy: 90.62%, Validation Accuracy: 79.46%
# Epoch [10/25], Step [25/280], Loss: 0.6584, Train Accuracy: 81.25%, Validation Accuracy: 80.45%
# Epoch [10/25], Step [50/280], Loss: 0.7140, Train Accuracy: 71.88%, Validation Accuracy: 78.39%
# Epoch [10/25], Step [75/280], Loss: 0.5539, Train Accuracy: 78.12%, Validation Accuracy: 78.39%
# Epoch [10/25], Step [100/280], Loss: 0.3473, Train Accuracy: 84.38%, Validation Accuracy: 80.09%
# Epoch [10/25], Step [125/280], Loss: 0.4944, Train Accuracy: 81.25%, Validation Accuracy: 80.18%
# Epoch [10/25], Step [150/280], Loss: 0.5686, Train Accuracy: 87.50%, Validation Accuracy: 81.16%
# Epoch [10/25], Step [175/280], Loss: 0.5975, Train Accuracy: 81.25%, Validation Accuracy: 79.20%
# Epoch [10/25], Step [200/280], Loss: 0.8710, Train Accuracy: 68.75%, Validation Accuracy: 79.02%
# Epoch [10/25], Step [225/280], Loss: 0.5782, Train Accuracy: 71.88%, Validation Accuracy: 80.00%
# Epoch [10/25], Step [250/280], Loss: 0.5587, Train Accuracy: 87.50%, Validation Accuracy: 81.34%
# Epoch [10/25], Step [275/280], Loss: 0.4307, Train Accuracy: 87.50%, Validation Accuracy: 81.52%
# Epoch [11/25], Step [25/280], Loss: 0.2469, Train Accuracy: 93.75%, Validation Accuracy: 81.52%
# Epoch [11/25], Step [50/280], Loss: 0.4882, Train Accuracy: 84.38%, Validation Accuracy: 82.86%
# Epoch [11/25], Step [75/280], Loss: 0.7320, Train Accuracy: 81.25%, Validation Accuracy: 79.55%
# Epoch [11/25], Step [100/280], Loss: 0.3558, Train Accuracy: 87.50%, Validation Accuracy: 82.50%
# Epoch [11/25], Step [125/280], Loss: 0.8259, Train Accuracy: 75.00%, Validation Accuracy: 80.98%
# Epoch [11/25], Step [150/280], Loss: 0.6286, Train Accuracy: 78.12%, Validation Accuracy: 81.34%
# Epoch [11/25], Step [175/280], Loss: 0.2999, Train Accuracy: 90.62%, Validation Accuracy: 83.57%
# Epoch [11/25], Step [200/280], Loss: 0.3331, Train Accuracy: 93.75%, Validation Accuracy: 80.45%
# Epoch [11/25], Step [225/280], Loss: 0.4468, Train Accuracy: 84.38%, Validation Accuracy: 79.91%
# Epoch [11/25], Step [250/280], Loss: 0.5355, Train Accuracy: 81.25%, Validation Accuracy: 79.02%
# Epoch [11/25], Step [275/280], Loss: 0.6204, Train Accuracy: 84.38%, Validation Accuracy: 82.77%
# Epoch [12/25], Step [25/280], Loss: 0.4854, Train Accuracy: 81.25%, Validation Accuracy: 81.61%
# Epoch [12/25], Step [50/280], Loss: 0.8712, Train Accuracy: 78.12%, Validation Accuracy: 81.79%
# Epoch [12/25], Step [75/280], Loss: 0.2998, Train Accuracy: 87.50%, Validation Accuracy: 83.84%
# Epoch [12/25], Step [100/280], Loss: 0.6819, Train Accuracy: 81.25%, Validation Accuracy: 81.25%
# Epoch [12/25], Step [125/280], Loss: 0.6350, Train Accuracy: 81.25%, Validation Accuracy: 81.07%
# Epoch [12/25], Step [150/280], Loss: 0.3875, Train Accuracy: 87.50%, Validation Accuracy: 83.39%
# Epoch [12/25], Step [175/280], Loss: 0.2933, Train Accuracy: 93.75%, Validation Accuracy: 81.25%
# Epoch [12/25], Step [200/280], Loss: 0.2479, Train Accuracy: 90.62%, Validation Accuracy: 78.48%
# Epoch [12/25], Step [225/280], Loss: 0.7057, Train Accuracy: 78.12%, Validation Accuracy: 82.95%
# Epoch [12/25], Step [250/280], Loss: 0.4943, Train Accuracy: 84.38%, Validation Accuracy: 84.11%
# Epoch [12/25], Step [275/280], Loss: 0.7433, Train Accuracy: 87.50%, Validation Accuracy: 76.70%
# Epoch [13/25], Step [25/280], Loss: 0.4116, Train Accuracy: 84.38%, Validation Accuracy: 83.21%
# Epoch [13/25], Step [50/280], Loss: 0.3821, Train Accuracy: 90.62%, Validation Accuracy: 81.07%
# Epoch [13/25], Step [75/280], Loss: 0.6168, Train Accuracy: 84.38%, Validation Accuracy: 82.59%
# Epoch [13/25], Step [100/280], Loss: 0.5169, Train Accuracy: 75.00%, Validation Accuracy: 79.73%
# Epoch [13/25], Step [125/280], Loss: 0.3408, Train Accuracy: 87.50%, Validation Accuracy: 79.82%
# Epoch [13/25], Step [150/280], Loss: 0.2175, Train Accuracy: 93.75%, Validation Accuracy: 81.70%
# Epoch [13/25], Step [175/280], Loss: 0.3308, Train Accuracy: 87.50%, Validation Accuracy: 84.64%
# Epoch [13/25], Step [200/280], Loss: 0.8381, Train Accuracy: 68.75%, Validation Accuracy: 79.82%
# Epoch [13/25], Step [225/280], Loss: 0.2280, Train Accuracy: 96.88%, Validation Accuracy: 82.23%
# Epoch [13/25], Step [250/280], Loss: 0.3772, Train Accuracy: 87.50%, Validation Accuracy: 81.43%
# Epoch [13/25], Step [275/280], Loss: 0.4259, Train Accuracy: 87.50%, Validation Accuracy: 81.52%
# Epoch [14/25], Step [25/280], Loss: 0.6676, Train Accuracy: 75.00%, Validation Accuracy: 83.21%
# Epoch [14/25], Step [50/280], Loss: 0.6738, Train Accuracy: 68.75%, Validation Accuracy: 82.05%
# Epoch [14/25], Step [75/280], Loss: 0.4050, Train Accuracy: 87.50%, Validation Accuracy: 79.20%
# Epoch [14/25], Step [100/280], Loss: 0.5146, Train Accuracy: 84.38%, Validation Accuracy: 84.46%
# Epoch [14/25], Step [125/280], Loss: 0.4290, Train Accuracy: 87.50%, Validation Accuracy: 83.57%
# Epoch [14/25], Step [150/280], Loss: 0.4112, Train Accuracy: 90.62%, Validation Accuracy: 84.91%
# Epoch [14/25], Step [175/280], Loss: 0.8399, Train Accuracy: 75.00%, Validation Accuracy: 84.02%
# Epoch [14/25], Step [200/280], Loss: 0.4635, Train Accuracy: 81.25%, Validation Accuracy: 84.55%
# Epoch [14/25], Step [225/280], Loss: 0.2707, Train Accuracy: 93.75%, Validation Accuracy: 84.64%
# Epoch [14/25], Step [250/280], Loss: 0.7174, Train Accuracy: 78.12%, Validation Accuracy: 82.59%
# Epoch [14/25], Step [275/280], Loss: 0.4371, Train Accuracy: 84.38%, Validation Accuracy: 85.00%
# Epoch [15/25], Step [25/280], Loss: 0.4002, Train Accuracy: 84.38%, Validation Accuracy: 85.09%
# Epoch [15/25], Step [50/280], Loss: 0.5256, Train Accuracy: 84.38%, Validation Accuracy: 84.46%
# Epoch [15/25], Step [75/280], Loss: 0.3781, Train Accuracy: 87.50%, Validation Accuracy: 85.89%
# Epoch [15/25], Step [100/280], Loss: 0.3453, Train Accuracy: 87.50%, Validation Accuracy: 83.39%
# Epoch [15/25], Step [125/280], Loss: 0.3859, Train Accuracy: 84.38%, Validation Accuracy: 84.02%
# Epoch [15/25], Step [150/280], Loss: 0.4322, Train Accuracy: 81.25%, Validation Accuracy: 83.66%
# Epoch [15/25], Step [175/280], Loss: 0.5859, Train Accuracy: 81.25%, Validation Accuracy: 85.54%
# Epoch [15/25], Step [200/280], Loss: 0.3010, Train Accuracy: 87.50%, Validation Accuracy: 84.46%
# Epoch [15/25], Step [225/280], Loss: 0.4239, Train Accuracy: 87.50%, Validation Accuracy: 84.38%
# Epoch [15/25], Step [250/280], Loss: 0.6033, Train Accuracy: 78.12%, Validation Accuracy: 82.86%
# Epoch [15/25], Step [275/280], Loss: 0.3545, Train Accuracy: 84.38%, Validation Accuracy: 84.02%
# Epoch [16/25], Step [25/280], Loss: 0.3228, Train Accuracy: 84.38%, Validation Accuracy: 84.91%
# Epoch [16/25], Step [50/280], Loss: 0.4059, Train Accuracy: 81.25%, Validation Accuracy: 80.27%
# Epoch [16/25], Step [75/280], Loss: 0.4248, Train Accuracy: 87.50%, Validation Accuracy: 83.66%
# Epoch [16/25], Step [100/280], Loss: 0.3101, Train Accuracy: 90.62%, Validation Accuracy: 82.86%
# Epoch [16/25], Step [125/280], Loss: 0.2146, Train Accuracy: 90.62%, Validation Accuracy: 83.66%
# Epoch [16/25], Step [150/280], Loss: 0.5998, Train Accuracy: 81.25%, Validation Accuracy: 85.45%
# Epoch [16/25], Step [175/280], Loss: 0.4328, Train Accuracy: 84.38%, Validation Accuracy: 85.18%
# Epoch [16/25], Step [200/280], Loss: 0.2765, Train Accuracy: 87.50%, Validation Accuracy: 85.45%
# Epoch [16/25], Step [225/280], Loss: 0.4092, Train Accuracy: 90.62%, Validation Accuracy: 86.88%
# Epoch [16/25], Step [250/280], Loss: 0.4393, Train Accuracy: 81.25%, Validation Accuracy: 83.21%
# Epoch [16/25], Step [275/280], Loss: 0.4182, Train Accuracy: 87.50%, Validation Accuracy: 83.30%
# Epoch [17/25], Step [25/280], Loss: 1.0919, Train Accuracy: 78.12%, Validation Accuracy: 85.27%
# Epoch [17/25], Step [50/280], Loss: 0.5598, Train Accuracy: 84.38%, Validation Accuracy: 85.18%
# Epoch [17/25], Step [75/280], Loss: 0.4345, Train Accuracy: 87.50%, Validation Accuracy: 85.54%
# Epoch [17/25], Step [100/280], Loss: 0.2701, Train Accuracy: 93.75%, Validation Accuracy: 85.62%
# Epoch [17/25], Step [125/280], Loss: 0.4258, Train Accuracy: 81.25%, Validation Accuracy: 84.11%
# Epoch [17/25], Step [150/280], Loss: 0.4278, Train Accuracy: 87.50%, Validation Accuracy: 83.12%
# Epoch [17/25], Step [175/280], Loss: 0.6137, Train Accuracy: 81.25%, Validation Accuracy: 86.34%
# Epoch [17/25], Step [200/280], Loss: 0.6309, Train Accuracy: 75.00%, Validation Accuracy: 87.41%
# Epoch [17/25], Step [225/280], Loss: 0.2724, Train Accuracy: 93.75%, Validation Accuracy: 85.27%
# Epoch [17/25], Step [250/280], Loss: 0.4770, Train Accuracy: 87.50%, Validation Accuracy: 86.34%
# Epoch [17/25], Step [275/280], Loss: 1.0556, Train Accuracy: 65.62%, Validation Accuracy: 82.50%
# Epoch [18/25], Step [25/280], Loss: 0.1569, Train Accuracy: 90.62%, Validation Accuracy: 84.91%
# Epoch [18/25], Step [50/280], Loss: 0.1958, Train Accuracy: 87.50%, Validation Accuracy: 86.43%
# Epoch [18/25], Step [75/280], Loss: 0.4729, Train Accuracy: 81.25%, Validation Accuracy: 86.34%
# Epoch [18/25], Step [100/280], Loss: 0.2831, Train Accuracy: 93.75%, Validation Accuracy: 86.07%
# Epoch [18/25], Step [125/280], Loss: 0.2304, Train Accuracy: 93.75%, Validation Accuracy: 86.88%
# Epoch [18/25], Step [150/280], Loss: 0.4063, Train Accuracy: 87.50%, Validation Accuracy: 86.52%
# Epoch [18/25], Step [175/280], Loss: 0.3537, Train Accuracy: 84.38%, Validation Accuracy: 86.70%
# Epoch [18/25], Step [200/280], Loss: 0.2668, Train Accuracy: 90.62%, Validation Accuracy: 87.41%
# Epoch [18/25], Step [225/280], Loss: 0.0948, Train Accuracy: 100.00%, Validation Accuracy: 86.79%
# Epoch [18/25], Step [250/280], Loss: 0.1547, Train Accuracy: 93.75%, Validation Accuracy: 86.79%
# Epoch [18/25], Step [275/280], Loss: 0.2946, Train Accuracy: 87.50%, Validation Accuracy: 86.70%
# Epoch [19/25], Step [25/280], Loss: 0.3557, Train Accuracy: 90.62%, Validation Accuracy: 84.11%
# Epoch [19/25], Step [50/280], Loss: 0.1847, Train Accuracy: 90.62%, Validation Accuracy: 86.34%
# Epoch [19/25], Step [75/280], Loss: 0.3183, Train Accuracy: 87.50%, Validation Accuracy: 88.48%
# Epoch [19/25], Step [100/280], Loss: 0.1301, Train Accuracy: 96.88%, Validation Accuracy: 87.59%
# Epoch [19/25], Step [125/280], Loss: 0.5706, Train Accuracy: 81.25%, Validation Accuracy: 83.30%
# Epoch [19/25], Step [150/280], Loss: 0.5080, Train Accuracy: 87.50%, Validation Accuracy: 84.73%
# Epoch [19/25], Step [175/280], Loss: 0.1304, Train Accuracy: 93.75%, Validation Accuracy: 87.32%
# Epoch [19/25], Step [200/280], Loss: 0.4202, Train Accuracy: 84.38%, Validation Accuracy: 87.14%
# Epoch [19/25], Step [225/280], Loss: 0.3134, Train Accuracy: 81.25%, Validation Accuracy: 87.23%
# Epoch [19/25], Step [250/280], Loss: 0.1815, Train Accuracy: 90.62%, Validation Accuracy: 86.16%
# Epoch [19/25], Step [275/280], Loss: 0.1971, Train Accuracy: 90.62%, Validation Accuracy: 87.32%
# Epoch [20/25], Step [25/280], Loss: 0.2693, Train Accuracy: 93.75%, Validation Accuracy: 87.05%
# Epoch [20/25], Step [50/280], Loss: 0.2878, Train Accuracy: 90.62%, Validation Accuracy: 86.61%
# Epoch [20/25], Step [75/280], Loss: 0.1737, Train Accuracy: 93.75%, Validation Accuracy: 86.43%
# Epoch [20/25], Step [100/280], Loss: 0.2143, Train Accuracy: 96.88%, Validation Accuracy: 87.77%
# Epoch [20/25], Step [125/280], Loss: 0.3051, Train Accuracy: 87.50%, Validation Accuracy: 86.25%
# Epoch [20/25], Step [150/280], Loss: 0.4522, Train Accuracy: 84.38%, Validation Accuracy: 86.70%
# Epoch [20/25], Step [175/280], Loss: 0.3765, Train Accuracy: 81.25%, Validation Accuracy: 86.61%
# Epoch [20/25], Step [200/280], Loss: 0.5492, Train Accuracy: 75.00%, Validation Accuracy: 84.73%
# Epoch [20/25], Step [225/280], Loss: 0.4559, Train Accuracy: 87.50%, Validation Accuracy: 87.05%
# Epoch [20/25], Step [250/280], Loss: 0.3731, Train Accuracy: 78.12%, Validation Accuracy: 86.25%
# Epoch [20/25], Step [275/280], Loss: 0.1483, Train Accuracy: 96.88%, Validation Accuracy: 85.71%
# Epoch [21/25], Step [25/280], Loss: 0.5737, Train Accuracy: 84.38%, Validation Accuracy: 86.96%
# Epoch [21/25], Step [50/280], Loss: 0.1798, Train Accuracy: 93.75%, Validation Accuracy: 86.16%
# Epoch [21/25], Step [75/280], Loss: 0.6297, Train Accuracy: 78.12%, Validation Accuracy: 87.68%
# Epoch [21/25], Step [100/280], Loss: 0.3297, Train Accuracy: 93.75%, Validation Accuracy: 87.77%
# Epoch [21/25], Step [125/280], Loss: 0.5077, Train Accuracy: 78.12%, Validation Accuracy: 88.39%
# Epoch [21/25], Step [150/280], Loss: 0.0791, Train Accuracy: 100.00%, Validation Accuracy: 86.61%
# Epoch [21/25], Step [175/280], Loss: 0.1632, Train Accuracy: 93.75%, Validation Accuracy: 88.12%
# Epoch [21/25], Step [200/280], Loss: 0.5369, Train Accuracy: 78.12%, Validation Accuracy: 87.32%
# Epoch [21/25], Step [225/280], Loss: 0.7423, Train Accuracy: 68.75%, Validation Accuracy: 86.25%
# Epoch [21/25], Step [250/280], Loss: 0.2612, Train Accuracy: 93.75%, Validation Accuracy: 87.50%
# Epoch [21/25], Step [275/280], Loss: 0.2364, Train Accuracy: 90.62%, Validation Accuracy: 88.84%
# Epoch [22/25], Step [25/280], Loss: 0.2275, Train Accuracy: 90.62%, Validation Accuracy: 88.48%
# Epoch [22/25], Step [50/280], Loss: 0.3735, Train Accuracy: 87.50%, Validation Accuracy: 87.23%
# Epoch [22/25], Step [75/280], Loss: 0.1687, Train Accuracy: 90.62%, Validation Accuracy: 87.41%
# Epoch [22/25], Step [100/280], Loss: 0.1820, Train Accuracy: 93.75%, Validation Accuracy: 86.07%
# Epoch [22/25], Step [125/280], Loss: 0.4822, Train Accuracy: 84.38%, Validation Accuracy: 88.04%
# Epoch [22/25], Step [150/280], Loss: 0.1566, Train Accuracy: 90.62%, Validation Accuracy: 84.38%
# Epoch [22/25], Step [175/280], Loss: 0.3806, Train Accuracy: 87.50%, Validation Accuracy: 86.25%
# Epoch [22/25], Step [200/280], Loss: 0.5607, Train Accuracy: 81.25%, Validation Accuracy: 85.09%
# Epoch [22/25], Step [225/280], Loss: 0.4007, Train Accuracy: 87.50%, Validation Accuracy: 88.04%
# Epoch [22/25], Step [250/280], Loss: 0.1188, Train Accuracy: 93.75%, Validation Accuracy: 85.89%
# Epoch [22/25], Step [275/280], Loss: 0.2198, Train Accuracy: 93.75%, Validation Accuracy: 87.50%
# Epoch [23/25], Step [25/280], Loss: 0.6883, Train Accuracy: 78.12%, Validation Accuracy: 85.62%
# Epoch [23/25], Step [50/280], Loss: 0.3409, Train Accuracy: 87.50%, Validation Accuracy: 88.04%
# Epoch [23/25], Step [75/280], Loss: 0.3246, Train Accuracy: 87.50%, Validation Accuracy: 87.86%
# Epoch [23/25], Step [100/280], Loss: 0.3706, Train Accuracy: 90.62%, Validation Accuracy: 86.70%
# Epoch [23/25], Step [125/280], Loss: 0.3033, Train Accuracy: 90.62%, Validation Accuracy: 86.96%
# Epoch [23/25], Step [150/280], Loss: 0.3466, Train Accuracy: 84.38%, Validation Accuracy: 87.68%
# Epoch [23/25], Step [175/280], Loss: 0.4653, Train Accuracy: 87.50%, Validation Accuracy: 85.27%
# Epoch [23/25], Step [200/280], Loss: 0.1360, Train Accuracy: 96.88%, Validation Accuracy: 87.05%
# Epoch [23/25], Step [225/280], Loss: 0.2876, Train Accuracy: 87.50%, Validation Accuracy: 85.80%
# Epoch [23/25], Step [250/280], Loss: 0.1316, Train Accuracy: 96.88%, Validation Accuracy: 85.18%
# Epoch [23/25], Step [275/280], Loss: 0.4587, Train Accuracy: 78.12%, Validation Accuracy: 85.62%
# Epoch [24/25], Step [25/280], Loss: 0.2598, Train Accuracy: 93.75%, Validation Accuracy: 88.66%
# Epoch [24/25], Step [50/280], Loss: 0.2326, Train Accuracy: 96.88%, Validation Accuracy: 87.95%
# Epoch [24/25], Step [75/280], Loss: 0.3465, Train Accuracy: 87.50%, Validation Accuracy: 87.68%
# Epoch [24/25], Step [100/280], Loss: 0.0668, Train Accuracy: 100.00%, Validation Accuracy: 88.39%
# Epoch [24/25], Step [125/280], Loss: 0.2627, Train Accuracy: 93.75%, Validation Accuracy: 87.41%
# Epoch [24/25], Step [150/280], Loss: 0.1004, Train Accuracy: 96.88%, Validation Accuracy: 87.05%
# Epoch [24/25], Step [175/280], Loss: 0.0988, Train Accuracy: 100.00%, Validation Accuracy: 88.30%
# Epoch [24/25], Step [200/280], Loss: 0.2890, Train Accuracy: 84.38%, Validation Accuracy: 89.46%
# Epoch [24/25], Step [225/280], Loss: 0.1473, Train Accuracy: 93.75%, Validation Accuracy: 86.07%
# Epoch [24/25], Step [250/280], Loss: 0.4791, Train Accuracy: 93.75%, Validation Accuracy: 87.59%
# Epoch [24/25], Step [275/280], Loss: 0.1446, Train Accuracy: 93.75%, Validation Accuracy: 88.66%
# Epoch [25/25], Step [25/280], Loss: 0.3134, Train Accuracy: 81.25%, Validation Accuracy: 87.23%
# Epoch [25/25], Step [50/280], Loss: 0.2672, Train Accuracy: 93.75%, Validation Accuracy: 86.16%
# Epoch [25/25], Step [75/280], Loss: 0.6316, Train Accuracy: 81.25%, Validation Accuracy: 84.02%
# Epoch [25/25], Step [100/280], Loss: 0.1663, Train Accuracy: 93.75%, Validation Accuracy: 85.09%
# Epoch [25/25], Step [125/280], Loss: 0.2181, Train Accuracy: 87.50%, Validation Accuracy: 86.88%
# Epoch [25/25], Step [150/280], Loss: 0.2724, Train Accuracy: 96.88%, Validation Accuracy: 86.88%
# Epoch [25/25], Step [175/280], Loss: 0.4540, Train Accuracy: 78.12%, Validation Accuracy: 86.96%
# Epoch [25/25], Step [200/280], Loss: 0.1310, Train Accuracy: 93.75%, Validation Accuracy: 88.39%
# Epoch [25/25], Step [225/280], Loss: 0.2478, Train Accuracy: 90.62%, Validation Accuracy: 89.11%
# Epoch [25/25], Step [250/280], Loss: 0.0499, Train Accuracy: 96.88%, Validation Accuracy: 86.70%
# Epoch [25/25], Step [275/280], Loss: 0.1516, Train Accuracy: 93.75%, Validation Accuracy: 87.95%
# ######## Training Finished in 6861.617549657822 seconds ###########

# %%
import numpy as np
import pandas as pd

COLUMN_NAMES=['num_of_epochs','training_accuracy','training_loss','validation_accuracy','validation_loss']
df = pd.DataFrame(np.hstack((num_of_epoch_array[:,None],training_accuracy_array[:,None], training_loss_array[:,None], validation_accuracy_array[:,None], validation_loss_array[:,None])), columns=COLUMN_NAMES)
df.columns

val = '{:.5f}'.format(validation_loss)
final_file = path['csv_file'] + str(val)
df.to_csv(final_file + '.csv', index=False, header=True)

# %%
visualize(model , train_loader)
# Out:
# [[0.05612154 0.32939216 0.03842521 ... 0.1586908  0.29965177 0.17022802]
#  [0.01234222 0.19862673 0.16913612 ... 0.22183861 0.6015839  0.28764722]
#  [0.8533814  0.25835964 0.30136621 ... 0.12073305 0.07899628 0.08270588]
#  ...
#  [0.57184041 0.81603163 0.17924507 ... 0.56938195 0.00385304 0.08111882]
#  [0.17802352 0.21218976 0.21913287 ... 0.         0.06118625 0.00352463]
#  [0.09672019 0.69357741 0.21662019 ... 0.19915043 0.1208875  0.0657464 ]]
# <ipython-input-18-abb40984a036>:36: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab20')

# %%
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from google.colab import drive

drive.mount('/content/drive')

final_file = '//content/drive/MyDrive/ai_results/flower_results/0.76735'
dataArray = np.genfromtxt(final_file + '.csv', delimiter=',', names=True)
print(dataArray)

log_dir = '/content/drive/MyDrive/some_directory/tensorboard_logs'  # Replace with your desired log directory
writer = SummaryWriter(log_dir)

for i, epoch in enumerate(dataArray['num_of_epochs']):
    writer.add_scalars(
        'loss/train',
        {'train_loss': dataArray['training_loss'][i], 'val_loss': dataArray['validation_loss'][i]},
        epoch
    )
    writer.add_scalars(
        'accuracy/train',
        {'train_accuracy': dataArray['training_accuracy'][i], 'val_accuracy': dataArray['validation_accuracy'][i]},
        epoch
    )

writer.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [( 1., 56.25 , 1.26272023, 54.375     , 1.337062  )
#  ( 2., 62.5  , 1.39162648, 61.60714286, 1.91207635)
#  ( 3., 75.   , 0.78424048, 68.03571429, 1.4020716 )
#  ( 4., 75.   , 0.90615851, 70.35714286, 0.66748798)
#  ( 5., 65.625, 0.71366376, 72.14285714, 0.97838426)
#  ( 6., 68.75 , 1.08021355, 75.80357143, 0.76242971)
#  ( 7., 81.25 , 0.57641369, 77.94642857, 0.82458198)
#  ( 8., 78.125, 0.55110067, 78.03571429, 0.75079346)
#  ( 9., 90.625, 0.37198862, 79.73214286, 0.8023985 )
#  (10., 87.5  , 0.43073282, 79.375     , 0.57142878)
#  (11., 84.375, 0.62035614, 81.60714286, 0.86397737)
#  (12., 87.5  , 0.74325329, 80.08928571, 0.94649976)
#  (13., 87.5  , 0.42593962, 80.89285714, 0.70095074)
#  (14., 84.375, 0.43711796, 85.625     , 0.53313184)
#  (15., 84.375, 0.3545199 , 83.75      , 0.55486864)
#  (16., 87.5  , 0.41818309, 84.64285714, 0.4932079 )
#  (17., 65.625, 1.05555892, 84.375     , 1.1979388 )
#  (18., 87.5  , 0.2945911 , 85.44642857, 0.56152242)
#  (19., 90.625, 0.19711411, 86.07142857, 0.29498929)
#  (20., 96.875, 0.14831036, 84.91071429, 0.86815768)
#  (21., 90.625, 0.2364444 , 86.33928571, 0.41094244)
#  (22., 93.75 , 0.21977177, 88.48214286, 0.70879632)
#  (23., 78.125, 0.45866337, 87.41071429, 0.47580928)
#  (24., 93.75 , 0.14462905, 87.85714286, 0.33720994)
#  (25., 93.75 , 0.15164794, 87.41071429, 0.76734525)]

# %%
model.eval()

with torch.no_grad():
    correct = 0
    total = 0
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print('Test Accuracy of the model on the {} test images: {} %'.format(total, (correct / total) * 100))
# Out:
# Test Accuracy of the model on the 1120 test images: 88.57142857142857 %

# %%
print("Unique y_expected labels:", set(y_expected))
print("Unique y_test labels:", set(y_test))
print("class2idx:", class2idx)
# Out:
# Unique y_expected labels: {tensor(0), tensor(1), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(5), tensor(6), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(4), tensor(4), tensor(5), tensor(5), tensor(6), tensor(1), tensor(2), tensor(4), tensor(6), tensor(6), tensor(5), tensor(0), tensor(3), tensor(3), tensor(6), tensor(6), tensor(6), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(2), tensor(3), tensor(3), tensor(3), tensor(4), tensor(6), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(6), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(4), tensor(5), tensor(4), tensor(6), tensor(6), tensor(6), tensor(1), tensor(2), tensor(6), tensor(0), tensor(0), tensor(3), tensor(5), tensor(6), tensor(6), tensor(4), tensor(6), tensor(6), tensor(6), tensor(6), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(6), tensor(6), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(4), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(4), tensor(5), tensor(6), tensor(6), tensor(6), tensor(1), tensor(2), tensor(6), tensor(4), tensor(5), tensor(0), tensor(3), tensor(3), tensor(4), tensor(5), tensor(6), tensor(6), tensor(6), tensor(5), tensor(6), tensor(4), tensor(1), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(3), tensor(5), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor(5), tensor(6), tensor(3), tensor(5), tensor(4), tensor(1), tensor(1), tensor(2), tensor(2), tensor(4), tensor(5), tensor(5), tensor(1), tensor(0), tensor(0), tensor(2), tensor(5), tensor(4), tensor(5), tensor(3), tensor(0), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(6), tensor(5), tensor(4), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(5), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(4), tensor(5), tensor(6), tensor(5), tensor(1), tensor(2), tensor(2), tensor(4), tensor(4), tensor(5), tensor(6), tensor(1), tensor(2), tensor(5), tensor(5), tensor(4), tensor(5), tensor(0), tensor(2), tensor(3), tensor(3), tensor(5), tensor(6), tensor(6), tensor(6), tensor(6), tensor(6), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(5), tensor(4), tensor(6), tensor(1), tensor(1), tensor(2), tensor(4), tensor(4), tensor(5), tensor(5), tensor(6), tensor(6), tensor(5), tensor(0), tensor(1), tensor(2), tensor(2), tensor(4), tensor(5), tensor(5), tensor(6), tensor(0), tensor(1), tensor(2), tensor(4), tensor(5), tensor(6), tensor(5), tensor(0), tensor(0), tensor(1), tensor(3), tensor(3), tensor(3), tensor(4), tensor(5), tensor(6), tensor(6), tensor(6), tensor(1), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(6), tensor(1), tensor(1), tensor(2), tensor(4), tensor(5), tensor(5), tensor(5), tensor(6), tensor(1), tensor(2), tensor(4), tensor(5), tensor(6), tensor(4), tensor(6), tensor(0), tensor(1), tensor(2), tensor(5), tensor(6), tensor(0), tensor(0), tensor(1), tensor(3), tensor(3), tensor(4), tensor(5), tensor(6), tensor(4), tensor(6), tensor(6), tensor(0), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(6), tensor(6), tensor(6), tensor(0), tensor(1), tensor(1), tensor(2), tensor(4), tensor(5), tensor(6), tensor(4), tensor(1), tensor(2), tensor(6), tensor(4), tensor(6), tensor(0), tensor(1), tensor(2), tensor(5), tensor(6), tensor(4), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), te ...
# Unique y_test labels: {tensor(3), tensor(3), tensor(6), tensor(3), tensor(1), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(6), tensor(3), tensor(1), tensor(4), tensor(4), tensor(4), tensor(0), tensor(0), tensor(4), tensor(0), tensor(0), tensor(2), tensor(2), tensor(4), tensor(4), tensor(5), tensor(5), tensor(5), tensor(6), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(2), tensor(4), tensor(4), tensor(1), tensor(2), tensor(3), tensor(5), tensor(5), tensor(5), tensor(6), tensor(5), tensor(0), tensor(1), tensor(6), tensor(0), tensor(4), tensor(0), tensor(0), tensor(0), tensor(3), tensor(3), tensor(3), tensor(2), tensor(4), tensor(4), tensor(5), tensor(6), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(3), tensor(1), tensor(5), tensor(2), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(4), tensor(6), tensor(4), tensor(4), tensor(2), tensor(3), tensor(6), tensor(6), tensor(1), tensor(3), tensor(0), tensor(0), tensor(0), tensor(2), tensor(3), tensor(3), tensor(3), tensor(3), tensor(3), tensor(4), tensor(4), tensor(5), tensor(6), tensor(0), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(4), tensor(6), tensor(0), tensor(1), tensor(2), tensor(2), tensor(2), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor(4), tensor(0), tensor(5), tensor(5), tensor(2), tensor(3), tensor(3), tensor(5), tensor(2), tensor(3), tensor(6), tensor(0), tensor(1), tensor(1), tensor(2), tensor(3), tensor(0), tensor(4), tensor(6), tensor(4), tensor(1), tensor(2), tensor(4), tensor(4), tensor(5), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(4), tensor(4), tensor(4), tensor(6), tensor(5), tensor(5), tensor(1), tensor(2), tensor(6), tensor(0), tensor(0), tensor(1), tensor(3), tensor(4), tensor(5), tensor(5), tensor(4), tensor(1), tensor(0), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(0), tensor(1), tensor(2), tensor(4), tensor(4), tensor(5), tensor(2), tensor(6), tensor(1), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(5), tensor(2), tensor(5), tensor(4), tensor(0), tensor(0), tensor(2), tensor(4), tensor(6), tensor(5), tensor(1), tensor(0), tensor(0), tensor(1), tensor(1), tensor(1), tensor(3), tensor(3), tensor(3), tensor(4), tensor(6), tensor(6), tensor(1), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor(2), tensor(2), tensor(6), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor(2), tensor(5), tensor(6), tensor(4), tensor(6), tensor(4), tensor(5), tensor(0), tensor(0), tensor(3), tensor(4), tensor(1), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(3), tensor(3), tensor(3), tensor(4), tensor(6), tensor(1), tensor(2), tensor(6), tensor(4), tensor(4), tensor(4), tensor(5), tensor(6), tensor(4), tensor(4), tensor(1), tensor(2), tensor(2), tensor(5), tensor(3), tensor(3), tensor(1), tensor(4), tensor(5), tensor(5), tensor(6), tensor(0), tensor(0), tensor(2), tensor(3), tensor(5), tensor(3), tensor(2), tensor(0), tensor(3), tensor(3), tensor(5), tensor(0), tensor(2), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(2), tensor(6), tensor(0), tensor(1), tensor(3), tensor(4), tensor(5), tensor(4), tensor(1), tensor(2), tensor(3), tensor(3), tensor(4), tensor(6), tensor(5), tensor(2), tensor(3), tensor(4), tensor(0), tensor(5), tensor(0), tensor(6), tensor(6), tensor(0), tensor(0), tensor(0), tensor(2), tensor(3), tensor(5), tensor(2), tensor(6), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(3), tensor(3), tensor(0), tensor(2), tensor(0), tensor(1), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(1), tensor(2), tensor(2), tensor(2), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor ...
# class2idx: {'Daisy': 0, 'Lavender': 1, 'Lily': 2, 'Rose': 3, 'Sunflower': 4}

# %%
class2idx = train_loader.dataset.class_to_idx
idx2class = {v: k for k, v in class2idx.items()}
print("Updated class2idx:", class2idx)
# Out:
# Updated class2idx: {'bellflower': 0, 'daisy': 1, 'dandelion': 2, 'lotus': 3, 'rose': 4, 'sunflower': 5, 'tulip': 6}

# %%
y_true = [idx2class[val.item()] for val in y_expected]
y_pred = [idx2class[val.item()] for val in y_test]

# %%
class2idx = train_loader.dataset.class_to_idx
idx2class = {v: k for k, v in class2idx.items()}
print("class2idx:", class2idx)

print("Unique labels in y_expected:", set(y_expected))
print("Unique labels in y_test:", set(y_test))

try:
    y_true = [idx2class[val.item()] for val in y_expected]
    y_pred = [idx2class[val.item()] for val in y_test]
except KeyError as e:
    print(f"KeyError: {e} - Check class2idx and dataset labels.")

print("First 10 y_true:", y_true[:10])
print("First 10 y_pred:", y_pred[:10])

macro_precision = precision_score(y_true, y_pred, average="macro")
macro_recall = recall_score(y_true, y_pred, average="macro")
micro_precision = precision_score(y_true, y_pred, average="micro")
micro_recall = recall_score(y_true, y_pred, average="micro")

cnf_matrix = confusion_matrix(y_true, y_pred, labels=list(class2idx.keys()))

plot_confusion_matrix(
    cnf_matrix, list(class2idx.keys()),
    [macro_precision, micro_precision, macro_recall, micro_recall],
    output_filename="confusion_matrix.png"
)
# Out:
# class2idx: {'bellflower': 0, 'daisy': 1, 'dandelion': 2, 'lotus': 3, 'rose': 4, 'sunflower': 5, 'tulip': 6}
# Unique labels in y_expected: {tensor(0), tensor(1), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(5), tensor(6), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(4), tensor(4), tensor(5), tensor(5), tensor(6), tensor(1), tensor(2), tensor(4), tensor(6), tensor(6), tensor(5), tensor(0), tensor(3), tensor(3), tensor(6), tensor(6), tensor(6), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(2), tensor(3), tensor(3), tensor(3), tensor(4), tensor(6), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(6), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(4), tensor(5), tensor(4), tensor(6), tensor(6), tensor(6), tensor(1), tensor(2), tensor(6), tensor(0), tensor(0), tensor(3), tensor(5), tensor(6), tensor(6), tensor(4), tensor(6), tensor(6), tensor(6), tensor(6), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(6), tensor(6), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(4), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(4), tensor(5), tensor(6), tensor(6), tensor(6), tensor(1), tensor(2), tensor(6), tensor(4), tensor(5), tensor(0), tensor(3), tensor(3), tensor(4), tensor(5), tensor(6), tensor(6), tensor(6), tensor(5), tensor(6), tensor(4), tensor(1), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(3), tensor(5), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor(5), tensor(6), tensor(3), tensor(5), tensor(4), tensor(1), tensor(1), tensor(2), tensor(2), tensor(4), tensor(5), tensor(5), tensor(1), tensor(0), tensor(0), tensor(2), tensor(5), tensor(4), tensor(5), tensor(3), tensor(0), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(6), tensor(5), tensor(4), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(5), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(5), tensor(4), tensor(5), tensor(6), tensor(5), tensor(1), tensor(2), tensor(2), tensor(4), tensor(4), tensor(5), tensor(6), tensor(1), tensor(2), tensor(5), tensor(5), tensor(4), tensor(5), tensor(0), tensor(2), tensor(3), tensor(3), tensor(5), tensor(6), tensor(6), tensor(6), tensor(6), tensor(6), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(5), tensor(4), tensor(6), tensor(1), tensor(1), tensor(2), tensor(4), tensor(4), tensor(5), tensor(5), tensor(6), tensor(6), tensor(5), tensor(0), tensor(1), tensor(2), tensor(2), tensor(4), tensor(5), tensor(5), tensor(6), tensor(0), tensor(1), tensor(2), tensor(4), tensor(5), tensor(6), tensor(5), tensor(0), tensor(0), tensor(1), tensor(3), tensor(3), tensor(3), tensor(4), tensor(5), tensor(6), tensor(6), tensor(6), tensor(1), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(6), tensor(1), tensor(1), tensor(2), tensor(4), tensor(5), tensor(5), tensor(5), tensor(6), tensor(1), tensor(2), tensor(4), tensor(5), tensor(6), tensor(4), tensor(6), tensor(0), tensor(1), tensor(2), tensor(5), tensor(6), tensor(0), tensor(0), tensor(1), tensor(3), tensor(3), tensor(4), tensor(5), tensor(6), tensor(4), tensor(6), tensor(6), tensor(0), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(6), tensor(6), tensor(6), tensor(0), tensor(1), tensor(1), tensor(2), tensor(4), tensor(5), tensor(6), tensor(4), tensor(1), tensor(2), tensor(6), tensor(4), tensor(6), tensor(0), tensor(1), tensor(2), tensor(5), tensor(6), tensor(4), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), ...
# Unique labels in y_test: {tensor(3), tensor(3), tensor(6), tensor(3), tensor(1), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(6), tensor(3), tensor(1), tensor(4), tensor(4), tensor(4), tensor(0), tensor(0), tensor(4), tensor(0), tensor(0), tensor(2), tensor(2), tensor(4), tensor(4), tensor(5), tensor(5), tensor(5), tensor(6), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(2), tensor(2), tensor(4), tensor(4), tensor(1), tensor(2), tensor(3), tensor(5), tensor(5), tensor(5), tensor(6), tensor(5), tensor(0), tensor(1), tensor(6), tensor(0), tensor(4), tensor(0), tensor(0), tensor(0), tensor(3), tensor(3), tensor(3), tensor(2), tensor(4), tensor(4), tensor(5), tensor(6), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(5), tensor(3), tensor(1), tensor(5), tensor(2), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(4), tensor(6), tensor(4), tensor(4), tensor(2), tensor(3), tensor(6), tensor(6), tensor(1), tensor(3), tensor(0), tensor(0), tensor(0), tensor(2), tensor(3), tensor(3), tensor(3), tensor(3), tensor(3), tensor(4), tensor(4), tensor(5), tensor(6), tensor(0), tensor(0), tensor(1), tensor(2), tensor(3), tensor(4), tensor(4), tensor(6), tensor(0), tensor(1), tensor(2), tensor(2), tensor(2), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor(4), tensor(0), tensor(5), tensor(5), tensor(2), tensor(3), tensor(3), tensor(5), tensor(2), tensor(3), tensor(6), tensor(0), tensor(1), tensor(1), tensor(2), tensor(3), tensor(0), tensor(4), tensor(6), tensor(4), tensor(1), tensor(2), tensor(4), tensor(4), tensor(5), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(4), tensor(4), tensor(4), tensor(6), tensor(5), tensor(5), tensor(1), tensor(2), tensor(6), tensor(0), tensor(0), tensor(1), tensor(3), tensor(4), tensor(5), tensor(5), tensor(4), tensor(1), tensor(0), tensor(0), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(0), tensor(1), tensor(2), tensor(4), tensor(4), tensor(5), tensor(2), tensor(6), tensor(1), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(5), tensor(2), tensor(5), tensor(4), tensor(0), tensor(0), tensor(2), tensor(4), tensor(6), tensor(5), tensor(1), tensor(0), tensor(0), tensor(1), tensor(1), tensor(1), tensor(3), tensor(3), tensor(3), tensor(4), tensor(6), tensor(6), tensor(1), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor(2), tensor(2), tensor(6), tensor(0), tensor(0), tensor(0), tensor(1), tensor(2), tensor(2), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), tensor(2), tensor(5), tensor(6), tensor(4), tensor(6), tensor(4), tensor(5), tensor(0), tensor(0), tensor(3), tensor(4), tensor(1), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(3), tensor(3), tensor(3), tensor(4), tensor(6), tensor(1), tensor(2), tensor(6), tensor(4), tensor(4), tensor(4), tensor(5), tensor(6), tensor(4), tensor(4), tensor(1), tensor(2), tensor(2), tensor(5), tensor(3), tensor(3), tensor(1), tensor(4), tensor(5), tensor(5), tensor(6), tensor(0), tensor(0), tensor(2), tensor(3), tensor(5), tensor(3), tensor(2), tensor(0), tensor(3), tensor(3), tensor(5), tensor(0), tensor(2), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(2), tensor(3), tensor(3), tensor(4), tensor(2), tensor(6), tensor(0), tensor(1), tensor(3), tensor(4), tensor(5), tensor(4), tensor(1), tensor(2), tensor(3), tensor(3), tensor(4), tensor(6), tensor(5), tensor(2), tensor(3), tensor(4), tensor(0), tensor(5), tensor(0), tensor(6), tensor(6), tensor(0), tensor(0), tensor(0), tensor(2), tensor(3), tensor(5), tensor(2), tensor(6), tensor(0), tensor(0), tensor(0), tensor(1), tensor(1), tensor(1), tensor(2), tensor(3), tensor(3), tensor(0), tensor(2), tensor(0), tensor(1), tensor(3), tensor(4), tensor(5), tensor(5), tensor(6), tensor(1), tensor(2), tensor(2), tensor(2), tensor(2), tensor(3), tensor(4), tensor(4), tensor(5), ten ...
# First 10 y_true: ['bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower']
# First 10 y_pred: ['bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower', 'bellflower']
